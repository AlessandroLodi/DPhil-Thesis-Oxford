# %%
import math
import scipy.constants as sc

# %%
e_r = 3.9 # relative permittivity SiO2. could also be 3.9
e_0 = sc.epsilon_0 # vacuum permittivity
e   = sc.e # elementary_charge

h   = 300e-9 # 300 nm is the distance from a backgate device
w   = 1.12e-9 # 1.12 nm is the MGNR width provided by our colleague chemists
l   = 100e-9 # the length here is just an estimate to see what the calcs yields
 
C   = 1e-15 # C is the total capacitance which includes Cs + Cg + Cd
 
Ec  = 1/2*C
Ec
# Out:
# 5e-16

# %%
Eadd = lambda l: e**2 * math.log(4*h/w) / (4*math.pi*e_0*e_r*l)
l    = lambda eadd: e**2 * math.log(4*h/w) / (4*math.pi*e_0*e_r*eadd) * 1e-9
l_atomic_unit    = lambda eadd: (math.log(4*h/w) / (4*math.pi*e_0*e_r*eadd)) * 1e-9
l_atomic_unit(156e-3)
# Out:
# 103.06358537788176

# %%
152e-3/(e*21e-3) # Edd / gate_couplig for the N -> N+1 transistion
# Out:
# 4.5176637110382666e+19

# %%
4*21e-3 # peak_spacing * gate_coupling (in eV)
# Out:
# 0.084

# %%
800/86
# Out:
# 9.30232558139535

# %%
180/86
# Out:
# 2.0930232558139537
